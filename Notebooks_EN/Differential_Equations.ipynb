# %% [markdown]
# 1. Solve the First-Order Ordinary Differential Equations Using the Method of Separation of Variables
#
# (a) Solve ￼
#
# Step-by-Step Solution:
# 	1.	Understand the equation:
# The given differential equation relates ￼ and its derivative ￼. Our goal is to find the general form of ￼.
# 	2.	Separate the variables:
# Rearrange the terms so that all ￼-dependent terms are on one side, and ￼-dependent terms are on the other:
# $$
# \frac{1}{y} , dy = dx
# $$
# This step is key in the separation of variables method.
# 	3.	Integrate both sides:
# Now, integrate both sides of the equation:
# $$
# \int \frac{1}{y} , dy = \int 1 , dx
# $$
# 	•	The left-hand side becomes:
# $$
# \int \frac{1}{y} , dy = \ln|y|
# $$
# 	•	The right-hand side becomes:
# $$
# \int 1 , dx = x + C
# $$
# 	4.	Combine the results:
# After integration, we have:
# $$
# \ln|y| = x + C
# $$
# 	5.	Solve for ￼:
# Exponentiate both sides to eliminate the logarithm:
# $$
# y = e^{x + C} = e^C e^x
# $$
# Let ￼ (a new constant):
# $$
# y(x) = C_1 e^x
# $$
#
# Final Solution:
# The general solution is:
# $$
# y(x) = C_1 e^x
# $$
# where ￼ is an arbitrary constant determined by initial conditions.
#
# (b) Solve ￼
#
# Step-by-Step Solution:
# 	1.	Understand the equation:
# This equation is similar to part (a), but instead of ￼, we have ￼ on the right-hand side.
# 	2.	Separate the variables:
# Move all ￼-dependent terms to one side and ￼-dependent terms to the other:
# $$
# \frac{1}{y} , dy = \frac{1}{2} , dx
# $$
# 	3.	Integrate both sides:
# $$
# \int \frac{1}{y} , dy = \int \frac{1}{2} , dx
# $$
# 	•	The left-hand side integrates to:
# $$
# \ln|y|
# $$
# 	•	The right-hand side integrates to:
# $$
# \frac{1}{2}x + C
# $$
# 	4.	Combine the results:
# $$
# \ln|y| = \frac{1}{2}x + C
# $$
# 	5.	Solve for ￼:
# Exponentiate both sides:
# $$
# y = e^{\frac{1}{2}x + C} = e^C e^{\frac{1}{2}x}
# $$
# Let ￼:
# $$
# y(x) = C_1 e^{\frac{1}{2}x}
# $$
#
# Final Solution:
# The general solution is:
# $$
# y(x) = C_1 e^{\frac{1}{2}x}
# $$
#
# (c) Solve ￼
#
# Step-by-Step Solution:
# 	1.	Understand the equation:
# Here, the derivative of ￼ depends on both ￼ and ￼. This is a first-order equation.
# 	2.	Separate the variables:
# Move ￼-dependent terms to one side and ￼-dependent terms to the other:
# $$
# \frac{1}{y} , dy = x , dx
# $$
# 	3.	Integrate both sides:
# $$
# \int \frac{1}{y} , dy = \int x , dx
# $$
# 	•	The left-hand side integrates to:
# $$
# \ln|y|
# $$
# 	•	The right-hand side integrates to:
# $$
# \frac{x^2}{2} + C
# $$
# 	4.	Combine the results:
# After integration, we have:
# $$
# \ln|y| = \frac{x^2}{2} + C
# $$
# 	5.	Solve for ￼:
# Exponentiate both sides to eliminate the logarithm:
# $$
# y = e^{\frac{x^2}{2} + C} = e^C e^{\frac{x^2}{2}}
# $$
# Let ￼:
# $$
# y(x) = C_1 e^{\frac{x^2}{2}}
# $$
#
# Final Solution:
# The general solution is:
# $$
# y(x) = C_1 e^{\frac{x^2}{2}}
# $$
#
# 2. Solve the Second-Order Ordinary Differential Equations
#
# (a) Solve ￼, with ￼ and ￼
#
# Step-by-Step Solution:
# 	1.	Rewrite the equation:
# Rearrange the equation:
# $$
# y’’(x) = -y’(x)
# $$
# 	2.	Solve the characteristic equation:
# Assume ￼. Substituting into the equation:
# $$
# rCe^{rx} = -Ce^{rx}
# $$
# Simplify:
# $$
# r = -1
# $$
# 	3.	Integrate to find ￼:
# Since ￼, integrate to find ￼:
# $$
# y(x) = -Ce^{-x} + D
# $$
# 	4.	Apply boundary conditions:
# 	•	Use ￼:
# $$
# -C + D = 2
# $$
# 	•	Use ￼:
# $$
# C = -1
# $$
# Substitute ￼ into ￼:
# $$
# -(-1) + D = 2 \implies D = 1
# $$
# 	5.	Final Solution:
# $$
# y(x) = e^{-x} + 1
# $$
#
# (b) Solve ￼, with ￼ and ￼
#
# Step-by-Step Solution:
# 	1.	Solve the characteristic equation:
# Assume ￼. Substituting:
# $$
# r^2 e^{rx} - e^{rx} = 0 \implies r^2 - 1 = 0
# $$
# Solve for ￼:
# $$
# r = \pm 1
# $$
# 	2.	General solution:
# The general solution is:
# $$
# y(x) = C_1 e^x + C_2 e^{-x}
# $$
# 	3.	Apply boundary conditions:
# 	•	Use ￼:
# $$
# C_1 + C_2 = 2
# $$
# 	•	Use ￼:
# $$
# y’(x) = C_1 e^x - C_2 e^{-x}, \quad y’(0) = C_1 - C_2 = 0
# $$
# From ￼, we get ￼. Substituting ￼:
# $$
# C_1 + C_2 = 2 \implies C_1 = C_2 = 1
# $$
# 	4.	Final Solution:
# $$
# y(x) = e^x + e^{-x}
# $$
