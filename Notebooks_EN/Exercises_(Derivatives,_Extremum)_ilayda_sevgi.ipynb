# %% [markdown]
# # **21. Derivatives**

# %% [markdown]
# **Task 1**
#
# Compute derivatives of functions:
#
# y
# (
# x
# )
# =
# −
# 3
# x
# +
# 3
# y
# (
# x
# )
# =
# π
# x
# +
# sin
# ⁡
# (
# 1
# )
# y
# (
# x
# )
# =
# 4
# +
# sin
# ⁡
# (
# 2
# )
# y
# (
# x
# )
# =
# 2
# x
# 3
# −
# 3
# x
# 2
# +
# 8
# x
# −
# 9
# y
# (
# x
# )
# =
# 6
# x
# 1
# /
# 3
# y
# (
# x
# )
# =
# x
# y
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# +
# sin
# ⁡
# (
# x
# )
# y
# (
# x
# )
# =
# 2
# sin
# ⁡
# (
# x
# )
# cos
# ⁡
# (
# x
# )
# y
# (
# x
# )
# =
# x
# sin
# ⁡
# (
# x
# )
# y
# (
# x
# )
# =
# (
# x
# +
# 1
# )
# (
# x
# +
# 1
# )
# y
# (
# x
# )
# =
# x
# x
# +
# 1
# y
# (
# x
# )
# =
# (
# x
# +
# 1
# )
# exp
# ⁡
# (
# x
# )
# y
# (
# x
# )
# =
# sin
# ⁡
# (
# x
# 2
# )
# y
# (
# x
# )
# =
# exp
# ⁡
# (
# −
# 2
# x
# )
# y
# (
# x
# )
# =
# 1
# sin
# ⁡
# (
# x
# +
# 1
# )
# y
# (
# x
# )
# =
# 2
# x
# +
# 1

# %% [markdown]
# 1.
# y
# (
# x
# )
# =
# −
# 3
# x
# +
# 3
# y(x)=−3x+3
# d
# y
# d
# x
# =
# d
# d
# x
# (
# −
# 3
# x
# +
# 3
# )
# =
# −
# 3.
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (−3x+3)=−3.

# %% [markdown]
# 2.
# y
# (
# x
# )
# =
# π
# x
# +
# sin
# ⁡
# (
# 1
# )
# y(x)=πx+sin(1)
# Since
# sin
# ⁡
# (
# 1
# )
# sin(1) is a constant, its derivative is zero:
#
# d
# y
# d
# x
# =
# d
# d
# x
# (
# π
# x
# +
# sin
# ⁡
# (
# 1
# )
# )
# =
# π
# .
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (πx+sin(1))=π.

# %% [markdown]
# 3.
# y
# (
# x
# )
# =
# 4
# +
# sin
# ⁡
# (
# 2
# )
# y(x)=4+sin(2)
# Since both 4 and
# sin
# ⁡
# (
# 2
# )
# sin(2) are constants, their derivative is zero:
#
# d
# y
# d
# x
# =
# d
# d
# x
# (
# 4
# +
# sin
# ⁡
# (
# 2
# )
# )
# =
# 0.
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (4+sin(2))=0.

# %% [markdown]
# 4.
# y
# (
# x
# )
# =
# 2
# x
# 3
# −
# 3
# x
# 2
# +
# 8
# x
# −
# 9
# y(x)=2x
# 3
#  −3x
# 2
#  +8x−9
# We differentiate each term using the power rule:
#
# d
# y
# d
# x
# =
# d
# d
# x
# (
# 2
# x
# 3
# −
# 3
# x
# 2
# +
# 8
# x
# −
# 9
# )
# =
# 6
# x
# 2
# −
# 6
# x
# +
# 8.
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (2x
# 3
#  −3x
# 2
#  +8x−9)=6x
# 2
#  −6x+8

# %% [markdown]
# 5.
# y
# (
# x
# )
# =
# 6
# x
# 1
# /
# 3
# y(x)=6x
# 1/3
#
# Use the power rule,
# d
# d
# x
# (
# x
# n
# )
# =
# n
# x
# n
# −
# 1
# dx
# d
# ​
#  (x
# n
#  )=nx
# n−1
#  :
#
# d
# y
# d
# x
# =
# d
# d
# x
# (
# 6
# x
# 1
# /
# 3
# )
# =
# 6
# ⋅
# 1
# 3
# x
# −
# 2
# /
# 3
# =
# 2
# x
# −
# 2
# /
# 3
# .
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (6x
# 1/3
#  )=6⋅
# 3
# 1
# ​
#  x
# −2/3
#  =2x
# −2/3
#  .

# %% [markdown]
# 6.
# y
# (
# x
# )
# =
# x
# y(x)=x
# The derivative of
# x
# x is simply:
#
# d
# y
# d
# x
# =
# 1.
# dx
# dy
# ​
#  =1.

# %% [markdown]
# 7.
# y
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# +
# sin
# ⁡
# (
# x
# )
# y(x)=cos(x)+sin(x)
# Using the derivatives of cosine and sine:
#
# d
# y
# d
# x
# =
# d
# d
# x
# (
# cos
# ⁡
# (
# x
# )
# +
# sin
# ⁡
# (
# x
# )
# )
# =
# −
# sin
# ⁡
# (
# x
# )
# +
# cos
# ⁡
# (
# x
# )
# .
# dx
# dy
# ​
#  =
# dx
# d
# ​
#  (cos(x)+sin(x))=−sin(x)+cos(x).

# %% [markdown]
# 8.
# y
# (
# x
# )
# =
# 2
# sin
# ⁡
# (
# x
# )
# cos
# ⁡
# (
# x
# )
# y(x)=2sin(x)cos(x)
# Use the product rule:
# d
# d
# x
# (
# u
# ⋅
# v
# )
# =
# u
# ′
# v
# +
# u
# v
# ′
# dx
# d
# ​
#  (u⋅v)=u
# ′
#  v+uv
# ′
#  .
#
# Let
# u
# =
# 2
# sin
# ⁡
# (
# x
# )
# u=2sin(x) and
# v
# =
# cos
# ⁡
# (
# x
# )
# v=cos(x). Then:
#
# u
# ′
# =
# 2
# cos
# ⁡
# (
# x
# )
# ,
# v
# ′
# =
# −
# sin
# ⁡
# (
# x
# )
# .
# u
# ′
#  =2cos(x),v
# ′
#  =−sin(x).
# Thus, applying the product rule:
#
# d
# y
# d
# x
# =
# 2
# cos
# ⁡
# (
# x
# )
# cos
# ⁡
# (
# x
# )
# +
# 2
# sin
# ⁡
# (
# x
# )
# (
# −
# sin
# ⁡
# (
# x
# )
# )
# =
# 2
# cos
# ⁡
# 2
# (
# x
# )
# −
# 2
# sin
# ⁡
# 2
# (
# x
# )
# .
# dx
# dy
# ​
#  =2cos(x)cos(x)+2sin(x)(−sin(x))=2cos
# 2
#  (x)−2sin
# 2
#  (x).
# This simplifies to:
#
# d
# y
# d
# x
# =
# 2
# (
# cos
# ⁡
# 2
# (
# x
# )
# −
# sin
# ⁡
# 2
# (
# x
# )
# )
# .
# dx
# dy
# ​
#  =2(cos
# 2
#  (x)−sin
# 2
#  (x)).

# %% [markdown]
# 9.
# y
# (
# x
# )
# =
# x
# sin
# ⁡
# (
# x
# )
# y(x)=xsin(x)
# Again, use the product rule:
#
# Let
# u
# =
# x
# u=x and
# v
# =
# sin
# ⁡
# (
# x
# )
# v=sin(x). Then:
#
# u
# ′
# =
# 1
# ,
# v
# ′
# =
# cos
# ⁡
# (
# x
# )
# .
# u
# ′
#  =1,v
# ′
#  =cos(x).
# Thus, applying the product rule:
#
# d
# y
# d
# x
# =
# x
# cos
# ⁡
# (
# x
# )
# +
# sin
# ⁡
# (
# x
# )
# .
# dx
# dy
# ​
#  =xcos(x)+sin(x).

# %% [markdown]
# 10.
# y
# (
# x
# )
# =
# (
# x
# +
# 1
# )
# (
# x
# +
# 1
# )
# y(x)=(x+1)(x+1)
# Simplify the expression first:
#
# y
# (
# x
# )
# =
# (
# x
# +
# 1
# )
# 2
# .
# y(x)=(x+1)
# 2
#  .
# Now differentiate using the power rule:
#
# d
# y
# d
# x
# =
# 2
# (
# x
# +
# 1
# )
# .
# dx
# dy
# ​
#  =2(x+1).

# %% [markdown]
# 1.
# y
# (
# x
# )
# =
# x
# x
# +
# 1
# y(x)=
# x+1
# x
# ​
#
# Use the quotient rule:
# d
# d
# x
# (
# u
# v
# )
# =
# u
# ′
# v
# −
# u
# v
# ′
# v
# 2
# dx
# d
# ​
#  (
# v
# u
# ​
#  )=
# v
# 2
#
# u
# ′
#  v−uv
# ′
#
# ​
#  .
#
# Let
# u
# =
# x
# u=x and
# v
# =
# x
# +
# 1
# v=x+1. Then:
#
# u
# ′
# =
# 1
# ,
# v
# ′
# =
# 1.
# u
# ′
#  =1,v
# ′
#  =1.
# Applying the quotient rule:
#
# d
# y
# d
# x
# =
# 1
# (
# x
# +
# 1
# )
# −
# x
# (
# 1
# )
# (
# x
# +
# 1
# )
# 2
# =
# x
# +
# 1
# −
# x
# (
# x
# +
# 1
# )
# 2
# =
# 1
# (
# x
# +
# 1
# )
# 2
# .
# dx
# dy
# ​
#  =
# (x+1)
# 2
#
# 1(x+1)−x(1)
# ​
#  =
# (x+1)
# 2
#
# x+1−x
# ​
#  =
# (x+1)
# 2
#
# 1
# ​
#  .

# %% [markdown]
# 12.
# y
# (
# x
# )
# =
# (
# x
# +
# 1
# )
# e
# x
# y(x)=(x+1)e
# x
#
# Use the product rule:
#
# Let
# u
# =
# (
# x
# +
# 1
# )
# u=(x+1) and
# v
# =
# e
# x
# v=e
# x
#  . Then:
#
# u
# ′
# =
# 1
# ,
# v
# ′
# =
# e
# x
# .
# u
# ′
#  =1,v
# ′
#  =e
# x
#  .
# Thus, applying the product rule:
#
# d
# y
# d
# x
# =
# (
# x
# +
# 1
# )
# e
# x
# +
# e
# x
# =
# (
# x
# +
# 2
# )
# e
# x
# .
# dx
# dy
# ​
#  =(x+1)e
# x
#  +e
# x
#  =(x+2)e
# x
#  .

# %% [markdown]
# 13.
# y
# (
# x
# )
# =
# sin
# ⁡
# (
# x
# 2
# )
# y(x)=sin(x
# 2
#  )
# Use the chain rule. Let
# u
# =
# x
# 2
# u=x
# 2
#  , so
# d
# d
# x
# (
# sin
# ⁡
# (
# u
# )
# )
# =
# cos
# ⁡
# (
# u
# )
# ⋅
# d
# u
# d
# x
# dx
# d
# ​
#  (sin(u))=cos(u)⋅
# dx
# du
# ​
#  . Then:
#
# d
# y
# d
# x
# =
# 2
# x
# ⋅
# cos
# ⁡
# (
# x
# 2
# )
# .
# dx
# dy
# ​
#  =2x⋅cos(x
# 2
#  ).

# %% [markdown]
# 14.
# y
# (
# x
# )
# =
# e
# −
# 2
# x
# y(x)=e
# −2x
#
# Use the chain rule. Let
# u
# =
# −
# 2
# x
# u=−2x, so
# d
# d
# x
# (
# e
# u
# )
# =
# e
# u
# ⋅
# d
# u
# d
# x
# dx
# d
# ​
#  (e
# u
#  )=e
# u
#  ⋅
# dx
# du
# ​
#  . Then:
#
# d
# y
# d
# x
# =
# −
# 2
# e
# −
# 2
# x
# .
# dx
# dy
# ​
#  =−2e
# −2x
#  .

# %% [markdown]
# 15.
# y
# (
# x
# )
# =
# 1
# sin
# ⁡
# (
# x
# +
# 1
# )
# y(x)=
# sin(x+1)
# 1
# ​
#
# Use the chain rule. Let
# u
# =
# x
# +
# 1
# u=x+1, so:
#
# d
# y
# d
# x
# =
# −
# cos
# ⁡
# (
# x
# +
# 1
# )
# sin
# ⁡
# 2
# (
# x
# +
# 1
# )
# .
# dx
# dy
# ​
#  =−
# sin
# 2
#  (x+1)
# cos(x+1)
# ​
#  .

# %% [markdown]
# 16.
# y
# (
# x
# )
# =
# 2
# x
# +
# 1
# y(x)=2x+1
# The derivative of this linear function is simply:
#
# d
# y
# d
# x
# =
# 2.
# dx
# dy
# ​
#  =2.

# %% [markdown]
# Summary of Derivatives:
# d
# y
# d
# x
# =
# −
# 3
# dx
# dy
# ​
#  =−3
# d
# y
# d
# x
# =
# π
# dx
# dy
# ​
#  =π
# d
# y
# d
# x
# =
# 0
# dx
# dy
# ​
#  =0
# d
# y
# d
# x
# =
# 6
# x
# 2
# −
# 6
# x
# +
# 8
# dx
# dy
# ​
#  =6x
# 2
#  −6x+8
# d
# y
# d
# x
# =
# 2
# x
# −
# 2
# /
# 3
# dx
# dy
# ​
#  =2x
# −2/3
#
# d
# y
# d
# x
# =
# 1
# dx
# dy
# ​
#  =1
# d
# y
# d
# x
# =
# −
# sin
# ⁡
# (
# x
# )
# +
# cos
# ⁡
# (
# x
# )
# dx
# dy
# ​
#  =−sin(x)+cos(x)
# d
# y
# d
# x
# =
# 2
# (
# cos
# ⁡
# 2
# (
# x
# )
# −
# sin
# ⁡
# 2
# (
# x
# )
# )
# dx
# dy
# ​
#  =2(cos
# 2
#  (x)−sin
# 2
#  (x))
# d
# y
# d
# x
# =
# x
# cos
# ⁡
# (
# x
# )
# +
# sin
# ⁡
# (
# x
# )
# dx
# dy
# ​
#  =xcos(x)+sin(x)
# d
# y
# d
# x
# =
# 2
# (
# x
# +
# 1
# )
# dx
# dy
# ​
#  =2(x+1)
# d
# y
# d
# x
# =
# 1
# (
# x
# +
# 1
# )
# 2
# dx
# dy
# ​
#  =
# (x+1)
# 2
#
# 1
# ​
#
# d
# y
# d
# x
# =
# (
# x
# +
# 2
# )
# e
# x
# dx
# dy
# ​
#  =(x+2)e
# x
#
# d
# y
# d
# x
# =
# 2
# x
# ⋅
# cos
# ⁡
# (
# x
# 2
# )
# dx
# dy
# ​
#  =2x⋅cos(x
# 2
#  )
# d
# y
# d
# x
# =
# −
# 2
# e
# −
# 2
# x
# dx
# dy
# ​
#  =−2e
# −2x
#
# d
# y
# d
# x
# =
# −
# cos
# ⁡
# (
# x
# +
# 1
# )
# sin
# ⁡
# 2
# (
# x
# +
# 1
# )
# dx
# dy
# ​
#  =−
# sin
# 2
#  (x+1)
# cos(x+1)
# ​
#
# d
# y
# d
# x
# =
# 2
# dx
# dy
# ​
#  =2

# %% [markdown]
# **Task 2**
#
# Prove:
#
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# cot
# ⁡
# (
# x
# )

# %% [markdown]
# Apply the chain rule
# We need to differentiate the composite function
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# ln(sin(x)). To do this, we apply the chain rule, which states that if
# y
# =
# ln
# ⁡
# (
# u
# )
# y=ln(u) where
# u
# =
# sin
# ⁡
# (
# x
# )
# u=sin(x), then:
#
# d
# d
# x
# ln
# ⁡
# (
# u
# )
# =
# 1
# u
# ⋅
# d
# u
# d
# x
# .
# dx
# d
# ​
#  ln(u)=
# u
# 1
# ​
#  ⋅
# dx
# du
# ​
#  .

# %% [markdown]
# Differentiate
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# ln(sin(x))
# Using the chain rule, we differentiate
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# ln(sin(x)):
#
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# 1
# sin
# ⁡
# (
# x
# )
# ⋅
# d
# d
# x
# (
# sin
# ⁡
# (
# x
# )
# )
# .
# dx
# d
# ​
#  (ln(sin(x)))=
# sin(x)
# 1
# ​
#  ⋅
# dx
# d
# ​
#  (sin(x)).
# Since the derivative of
# sin
# ⁡
# (
# x
# )
# sin(x) is
# cos
# ⁡
# (
# x
# )
# cos(x), we get:
#
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# 1
# sin
# ⁡
# (
# x
# )
# ⋅
# cos
# ⁡
# (
# x
# )
# .
# dx
# d
# ​
#  (ln(sin(x)))=
# sin(x)
# 1
# ​
#  ⋅

# %% [markdown]
# Simplify the expression
# Now, we simplify:
#
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# cos
# ⁡
# (
# x
# )
# sin
# ⁡
# (
# x
# )
# .
# dx
# d
# ​
#  (ln(sin(x)))=
# sin(x)
# cos(x)
# ​
#  .

# %% [markdown]
# Recognize the result
# We recognize that
# cos
# ⁡
# (
# x
# )
# sin
# ⁡
# (
# x
# )
# sin(x)
# cos(x)
# ​
#   is the definition of
# cot
# ⁡
# (
# x
# )
# cot(x). Therefore, we can conclude:
#
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# cot
# ⁡
# (
# x
# )
# .
# dx
# d
# ​
#  (ln(sin(x)))=cot(x).

# %% [markdown]
# Final Conclusion:
# d
# d
# x
# (
# ln
# ⁡
# (
# sin
# ⁡
# (
# x
# )
# )
# )
# =
# cot
# ⁡
# (
# x
# )
# .
# dx
# d
# ​
#  (ln(sin(x)))=cot(x)
# ​
#  .

# %% [markdown]
# **Task 3**
#
# For
# f
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# , verify that
# f
# ″
# (
# x
# )
# =
# −
# f
# (
# x
# )
# .

# %% [markdown]
# Compute the first derivative of
# f
# (
# x
# )
# f(x)
# The first derivative of
# f
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# f(x)=cos(x) is:
#
# f
# ′
# (
# x
# )
# =
# d
# d
# x
# cos
# ⁡
# (
# x
# )
# =
# −
# sin
# ⁡
# (
# x
# )
# .
# f
# ′
#  (x)=
# dx
# d
# ​
#  cos(x)=−sin(x).

# %% [markdown]
# Compute the second derivative of
# f
# (
# x
# )
# f(x)
# Now, we compute the second derivative of
# f
# (
# x
# )
# f(x) by differentiating
# f
# ′
# (
# x
# )
# =
# −
# sin
# ⁡
# (
# x
# )
# f
# ′
#  (x)=−sin(x):
#
# f
# ′
# ′
# (
# x
# )
# =
# d
# d
# x
# (
# −
# sin
# ⁡
# (
# x
# )
# )
# =
# −
# cos
# ⁡
# (
# x
# )
# .
# f
# ′′
#  (x)=
# dx
# d
# ​
#  (−sin(x))=−cos(x)

# %% [markdown]
# Verify the relationship
# We have found that:
#
# f
# ′
# ′
# (
# x
# )
# =
# −
# cos
# ⁡
# (
# x
# )
# .
# f
# ′′
#  (x)=−cos(x).
# Recall that
# f
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# f(x)=cos(x). Therefore:
#
# f
# ′
# ′
# (
# x
# )
# =
# −
# f
# (
# x
# )
# .
# f
# ′′
#  (x)=−f(x).

# %% [markdown]
# Thus, we have verified that for
# f
# (
# x
# )
# =
# cos
# ⁡
# (
# x
# )
# f(x)=cos(x), the second derivative satisfies:
#
# f
# ′
# ′
# (
# x
# )
# =
# −
# f
# (
# x
# )
# .
# f
# ′′
#  (x)=−f(x).

# %% [markdown]
# **Task 4 **
#
# Using de l'Hospital's Rule, find the improper limits:
#
# lim
# x
# →
# 0
# sin
# ⁡
# x
# x
#
# lim
# x
# →
# ∞
# ln
# ⁡
# x
# x
#
# lim
# x
# →
# ∞
# exp
# ⁡
# (
# x
# )
# x

# %% [markdown]
# lim
# ⁡
# x
# →
# 0
# sin
# ⁡
# (
# x
# )
# x
# lim
# x→0
# ​
#
# x
# sin(x)
# ​
#
# This is a classic limit and can be evaluated using L'Hôpital's Rule. First, notice that as
# x
# →
# 0
# x→0, both the numerator
# sin
# ⁡
# (
# x
# )
# sin(x) and the denominator
# x
# x approach 0, resulting in an indeterminate form
# 0
# 0
# 0
# 0
# ​
#  . Thus, we can apply L'Hôpital's Rule:
#
# L'Hôpital's Rule states that if a limit has the form
# 0
# 0
# 0
# 0
# ​
#  , we differentiate the numerator and the denominator separately and then take the limit:
#
# lim
# ⁡
# x
# →
# 0
# sin
# ⁡
# (
# x
# )
# x
# =
# lim
# ⁡
# x
# →
# 0
# d
# d
# x
# sin
# ⁡
# (
# x
# )
# d
# d
# x
# x
# =
# lim
# ⁡
# x
# →
# 0
# cos
# ⁡
# (
# x
# )
# 1
# .
# x→0
# lim
# ​
#
# x
# sin(x)
# ​
#  =
# x→0
# lim
# ​
#
# dx
# d
# ​
#  x
# dx
# d
# ​
#  sin(x)
# ​
#  =
# x→0
# lim
# ​
#
# 1
# cos(x)
# ​
#  .
# Now, evaluate the limit:
#
# lim
# ⁡
# x
# →
# 0
# cos
# ⁡
# (
# x
# )
# 1
# =
# cos
# ⁡
# (
# 0
# )
# =
# 1.
# x→0
# lim
# ​
#
# 1
# cos(x)
# ​
#  =cos(0)=1.
# So,
#
# lim
# ⁡
# x
# →
# 0
# sin
# ⁡
# (
# x
# )
# x
# =
# 1.
# x→0
# lim
# ​
#
# x
# sin(x)
# ​
#  =1

# %% [markdown]
# 2.
# lim
# ⁡
# x
# →
# ∞
# ln
# ⁡
# (
# x
# )
# x
# lim
# x→∞
# ​
#
# x
# ln(x)
# ​
#
# This is an indeterminate form
# ∞
# ∞
# ∞
# ∞
# ​
#  , so we can apply L'Hôpital's Rule again. First, differentiate the numerator and the denominator:
#
# lim
# ⁡
# x
# →
# ∞
# ln
# ⁡
# (
# x
# )
# x
# =
# lim
# ⁡
# x
# →
# ∞
# d
# d
# x
# ln
# ⁡
# (
# x
# )
# d
# d
# x
# x
# =
# lim
# ⁡
# x
# →
# ∞
# 1
# x
# 1
# .
# x→∞
# lim
# ​
#
# x
# ln(x)
# ​
#  =
# x→∞
# lim
# ​
#
# dx
# d
# ​
#  x
# dx
# d
# ​
#  ln(x)
# ​
#  =
# x→∞
# lim
# ​
#
# 1
# x
# 1
# ​
#
# ​
#  .
# Now, evaluate the limit:
#
# lim
# ⁡
# x
# →
# ∞
# 1
# x
# =
# 0.
# x→∞
# lim
# ​
#
# x
# 1
# ​
#  =0.
# So,
#
# lim
# ⁡
# x
# →
# ∞
# ln
# ⁡
# (
# x
# )
# x
# =
# 0.
# x→∞
# lim
# ​
#
# x
# ln(x)
# ​
#  =0.

# %% [markdown]
# 3.
# lim
# ⁡
# x
# →
# ∞
# e
# x
# x
# lim
# x→∞
# ​
#
# x
# e
# x
#
# ​
#
# This is also an indeterminate form
# ∞
# ∞
# ∞
# ∞
# ​
#  , so we apply L'Hôpital's Rule once more. Differentiate the numerator and the denominator:
#
# lim
# ⁡
# x
# →
# ∞
# e
# x
# x
# =
# lim
# ⁡
# x
# →
# ∞
# d
# d
# x
# e
# x
# d
# d
# x
# x
# =
# lim
# ⁡
# x
# →
# ∞
# e
# x
# 1
# .
# x→∞
# lim
# ​
#
# x
# e
# x
#
# ​
#  =
# x→∞
# lim
# ​
#
# dx
# d
# ​
#  x
# dx
# d
# ​
#  e
# x
#
# ​
#  =
# x→∞
# lim
# ​
#
# 1
# e
# x
#
# ​
#  .
# Now, evaluate the limit:
#
# lim
# ⁡
# x
# →
# ∞
# e
# x
# =
# ∞
# .
# x→∞
# lim
# ​
#  e
# x
#  =∞.
# So,
#
# lim
# ⁡
# x
# →
# ∞
# e
# x
# x
# =
# ∞
# .
# x→∞
# lim
# ​
#
# x
# e
# x
#
# ​
#  =∞.

# %% [markdown]
# Final Answers:
# lim
# ⁡
# x
# →
# 0
# sin
# ⁡
# (
# x
# )
# x
# =
# 1
# lim
# x→0
# ​
#
# x
# sin(x)
# ​
#  =1
# lim
# ⁡
# x
# →
# ∞
# ln
# ⁡
# (
# x
# )
# x
# =
# 0
# lim
# x→∞
# ​
#
# x
# ln(x)
# ​
#  =0
# lim
# ⁡
# x
# →
# ∞
# e
# x
# x
# =
# ∞
# lim
# x→∞
# ​
#
# x
# e
# x
#
# ​
#  =∞

# %% [markdown]
# **Task 5**
#
# In physics, the position of a particle is given by
# x
# (
# t
# )
# =
# 3
# t
# 2
# −
# 6
# t
# +
# 1
# . Find the velocity
# V
# (
# t
# )
# =
# x
# ′
# (
# t
# )
#  and acceleration
# a
# (
# t
# )
# =
# V
# ′
# (
# t
# )
# =
# x
# ″
# (
# t
# )
#  of the particle at time
# t
# =
# 2
# .

# %% [markdown]
# Find the velocity
# V
# (
# t
# )
# V(t)
# The velocity is the derivative of the position function
# x
# (
# t
# )
# x(t). So, we differentiate
# x
# (
# t
# )
# x(t) with respect to
# t
# t:
#
# V
# (
# t
# )
# =
# d
# d
# t
# (
# 3
# t
# 2
# −
# 6
# t
# +
# 1
# )
# .
# V(t)=
# dt
# d
# ​
#  (3t
# 2
#  −6t+1).
# Applying the power rule:
#
# V
# (
# t
# )
# =
# 6
# t
# −
# 6.
# V(t)=6t−6.

# %% [markdown]
# Find the acceleration
# a
# (
# t
# )
# a(t)
# The acceleration is the derivative of the velocity function
# V
# (
# t
# )
# V(t). So, we differentiate
# V
# (
# t
# )
# =
# 6
# t
# −
# 6
# V(t)=6t−6 with respect to
# t
# t:
#
# a
# (
# t
# )
# =
# d
# d
# t
# (
# 6
# t
# −
# 6
# )
# .
# a(t)=
# dt
# d
# ​
#  (6t−6).
# This gives:
#
# a
# (
# t
# )
# =
# 6.
# a(t)=6.

# %% [markdown]
# Evaluate the velocity and acceleration at
# t
# =
# 2
# t=2
# Now, we evaluate
# V
# (
# t
# )
# V(t) and
# a
# (
# t
# )
# a(t) at
# t
# =
# 2
# t=2.
#
# For the velocity:
# V
# (
# 2
# )
# =
# 6
# (
# 2
# )
# −
# 6
# =
# 12
# −
# 6
# =
# 6.
# V(2)=6(2)−6=12−6=6.
# For the acceleration:
# a
# (
# 2
# )
# =
# 6.
# a(2)=6.

# %% [markdown]
# Final Answers:
# The velocity at
# t
# =
# 2
# t=2 is
# V
# (
# 2
# )
# =
# 6
# V(2)=6.
# The acceleration at
# t
# =
# 2
# t=2 is
# a
# (
# 2
# )
# =
# 6
# a(2)=6.

# %% [markdown]
# # **22. Extremum**

# %% [markdown]
# **Task 1 **
#
# The profit function is
# P
# (
# u
# )
# =
# −
# 2
# u
# 2
# +
# 50
# u
# −
# 300
# , where
# u
#  is the number of units sold. Find the number of units that maximize profit.

# %% [markdown]
# Find the critical points by taking the derivative
# To maximize the profit, we first find the derivative of
# P
# (
# u
# )
# P(u), which represents the rate of change of profit with respect to the number of units sold. We will set the derivative equal to zero to find the critical points.
#
# P
# ′
# (
# u
# )
# =
# d
# d
# u
# (
# −
# 2
# u
# 2
# +
# 50
# u
# −
# 300
# )
# .
# P
# ′
#  (u)=
# du
# d
# ​
#  (−2u
# 2
#  +50u−300).
# Using the power rule for derivatives:
#
# P
# ′
# (
# u
# )
# =
# −
# 4
# u
# +
# 50.
# P
# ′
#  (u)=−4u+50.

# %% [markdown]
# Set the derivative equal to zero to find critical points
# To find the value of
# u
# u that maximizes profit, we set
# P
# ′
# (
# u
# )
# =
# 0
# P
# ′
#  (u)=0:
#
# −
# 4
# u
# +
# 50
# =
# 0.
# −4u+50=0.
# Solving for
# u
# u:
#
# 4
# u
# =
# 50
# ⇒
# u
# =
# 50
# 4
# =
# 12.5.
# 4u=50⇒u=
# 4
# 50
# ​
#  =12.5.

# %% [markdown]
# Verify that this is a maximum
# To confirm that
# u
# =
# 12.5
# u=12.5 corresponds to a maximum, we can check the second derivative
# P
# ′
# ′
# (
# u
# )
# P
# ′′
#  (u). If
# P
# ′
# ′
# (
# u
# )
# P
# ′′
#  (u) is negative, then the function is concave down, and
# u
# =
# 12.5
# u=12.5 is a maximum.
#
# First, compute the second derivative:
#
# P
# ′
# ′
# (
# u
# )
# =
# d
# d
# u
# (
# −
# 4
# u
# +
# 50
# )
# =
# −
# 4.
# P
# ′′
#  (u)=
# du
# d
# ​
#  (−4u+50)=−4.
# Since
# P
# ′
# ′
# (
# u
# )
# =
# −
# 4
# P
# ′′
#  (u)=−4 is negative, the function is concave down at
# u
# =
# 12.5
# u=12.5, confirming that this is a maximum.

# %% [markdown]
# Final Answer:
# The number of units that maximize profit is
# 12.5.
#
# ​

# %% [markdown]
# **Task 2**
#
# You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.

# %% [markdown]
# Let the dimensions of the rectangle be:
#
# Length:
# L
# L
# Width:
# W
# W
# The total perimeter of the rectangle is given by the formula:
#
# Perimeter
# =
# 2
# L
# +
# 2
# W
# .
# Perimeter=2L+2W.
# We are given that the total length of the string is 10 meters, so the perimeter constraint is:
#
# 2
# L
# +
# 2
# W
# =
# 10.
# 2L+2W=10.
# Simplify the equation:
#
# L
# +
# W
# =
# 5.
# L+W=5.

# %% [markdown]
# Write the area function
# The area
# A
# A of the rectangle is given by:
#
# A
# =
# L
# ×
# W
# .
# A=L×W.

# %% [markdown]
# Express the area as a function of one variable
# We already know that
# L
# +
# W
# =
# 5
# L+W=5, so we can express
# W
# W in terms of
# L
# L:
#
# W
# =
# 5
# −
# L
# .
# W=5−L.
# Substitute this into the area formula:
#
# A
# (
# L
# )
# =
# L
# ×
# (
# 5
# −
# L
# )
# =
# 5
# L
# −
# L
# 2
# .
# A(L)=L×(5−L)=5L−L
# 2
#  .

# %% [markdown]
# Maximize the area
# To find the value of
# L
# L that maximizes the area, we take the derivative of
# A
# (
# L
# )
# A(L) with respect to
# L
# L and set it equal to 0.
#
# A
# ′
# (
# L
# )
# =
# d
# d
# L
# (
# 5
# L
# −
# L
# 2
# )
# =
# 5
# −
# 2
# L
# .
# A
# ′
#  (L)=
# dL
# d
# ​
#  (5L−L
# 2
#  )=5−2L.
# Set the derivative equal to 0 to find the critical points:
#
# 5
# −
# 2
# L
# =
# 0
# ⇒
# 2
# L
# =
# 5
# ⇒
# L
# =
# 5
# 2
# =
# 2.5.
# 5−2L=0⇒2L=5⇒L=
# 2
# 5
# ​
#  =2.5.

# %% [markdown]
# Verify that this is a maximum
# To verify that
# L
# =
# 2.5
# L=2.5 corresponds to a maximum, we compute the second derivative of the area function:
#
# A
# ′
# ′
# (
# L
# )
# =
# d
# d
# L
# (
# 5
# −
# 2
# L
# )
# =
# −
# 2.
# A
# ′′
#  (L)=
# dL
# d
# ​
#  (5−2L)=−2.
#  Since
# A
# ′
# ′
# (
# L
# )
# =
# −
# 2
# A
# ′′
#  (L)=−2 is negative, the function is concave down, and
# L
# =
# 2.5
# L=2.5 is indeed a maximum.

# %% [markdown]
# Find the width
# Using the perimeter constraint
# L
# +
# W
# =
# 5
# L+W=5, and
# L
# =
# 2.5
# L=2.5, we find:
#
# W
# =
# 5
# −
# 2.5
# =
# 2.5.
# W=5−2.5=2.5.

# %% [markdown]
# Final Answer:
# The dimensions of the rectangle that maximize the area are:
#
# 2.5
#  meters
# ×
# 2.5
#  meters
# .
# 2.5 meters×2.5 meters
# ​
#  .
# Thus, the rectangle is a square with side lengths of 2.5 meters.

# %% [markdown]
# **Task 3**
#
# Find extremum od
# f
# (
# x
# )
# =
# x
# 2
# +
# 3
# x
# −
# 5
# .

# %% [markdown]
# Compute the first derivative
# The first derivative of
# f
# (
# x
# )
# =
# x
# 2
# +
# 3
# x
# −
# 5
# f(x)=x
# 2
#  +3x−5 gives us the rate of change of the function with respect to
# x
# x. Using basic rules of differentiation:
#
# f
# ′
# (
# x
# )
# =
# d
# d
# x
# (
# x
# 2
# )
# +
# d
# d
# x
# (
# 3
# x
# )
# −
# d
# d
# x
# (
# 5
# )
# .
# f
# ′
#  (x)=
# dx
# d
# ​
#  (x
# 2
#  )+
# dx
# d
# ​
#  (3x)−
# dx
# d
# ​
#  (5).
# Differentiating term by term:
#
# f
# ′
# (
# x
# )
# =
# 2
# x
# +
# 3.
# f
# ′
#  (x)=2x+3.

# %% [markdown]
# Find the critical points
# To find the critical points, set the first derivative equal to zero:
#
# 2
# x
# +
# 3
# =
# 0.
# 2x+3=0.
# Solve for
# x
# x:
#
# 2
# x
# =
# −
# 3
# ⇒
# x
# =
# −
# 3
# 2
# .
# 2x=−3⇒x=−
# 2
# 3
# ​
#  .

# %% [markdown]
# Step 3: Determine the nature of the critical point
# To determine whether this critical point is a maximum, minimum, or a saddle point, we need to compute the second derivative of
# f
# (
# x
# )
# f(x).
#
# f
# ′
# ′
# (
# x
# )
# =
# d
# d
# x
# (
# 2
# x
# +
# 3
# )
# =
# 2.
# f
# ′′
#  (x)=
# dx
# d
# ​
#  (2x+3)=2.
# Since the second derivative is positive (
# f
# ′
# ′
# (
# x
# )
# =
# 2
# >
# 0
# f
# ′′
#  (x)=2>0), this indicates that the function is concave up at
# x
# =
# −
# 3
# 2
# x=−
# 2
# 3
# ​
#  , meaning the function has a local minimum at this point.

# %% [markdown]
# Find the minimum value
# To find the value of the function at this critical point, substitute
# x
# =
# −
# 3
# 2
# x=−
# 2
# 3
# ​
#   into the original function
# f
# (
# x
# )
# =
# x
# 2
# +
# 3
# x
# −
# 5
# f(x)=x
# 2
#  +3x−5:
#
# f
# (
# −
# 3
# 2
# )
# =
# (
# −
# 3
# 2
# )
# 2
# +
# 3
# (
# −
# 3
# 2
# )
# −
# 5.
# f(−
# 2
# 3
# ​
#  )=(−
# 2
# 3
# ​
#  )
# 2
#  +3(−
# 2
# 3
# ​
#  )−5.
# Simplifying:
#
# f
# (
# −
# 3
# 2
# )
# =
# 9
# 4
# −
# 9
# 2
# −
# 5.
# f(−
# 2
# 3
# ​
#  )=
# 4
# 9
# ​
#  −
# 2
# 9
# ​
#  −5.
# Convert everything to fractions with a denominator of 4:
#
# f
# (
# −
# 3
# 2
# )
# =
# 9
# 4
# −
# 18
# 4
# −
# 20
# 4
# =
# 9
# −
# 18
# −
# 20
# 4
# =
# −
# 29
# 4
# .
# f(−
# 2
# 3
# ​
#  )=
# 4
# 9
# ​
#  −
# 4
# 18
# ​
#  −
# 4
# 20
# ​
#  =
# 4
# 9−18−20
# ​
#  =
# 4
# −29
# ​
#  .
# So, the minimum value of the function is:
#
# f
# (
# −
# 3
# 2
# )
# =
# −
# 29
# 4
# .
# f(−
# 2
# 3
# ​
#  )=−
# 4
# 29
# ​
#  .

# %% [markdown]
# Final Answer:
# The function
# f
# (
# x
# )
# =
# x
# 2
# +
# 3
# x
# −
# 5
# f(x)=x
# 2
#  +3x−5 has a local minimum at
# x
# =
# −
# 3
# 2
# x=−
# 2
# 3
# ​
#  .
# The minimum value of the function is
# −
# 29
# 4
# −
# 4
# 29
# ​
#  .

# %% [markdown]
# **Task 4**
#
# Find extremum of
# f
# (
# x
# )
# =
# x
# 2
# +
# 2
# x
# +
# 1
# x
# −
# 1
# .

# %% [markdown]
# Find the first derivative using the quotient rule
# The function is a quotient, so we apply the quotient rule for differentiation:
#
# d
# d
# x
# (
# u
# (
# x
# )
# v
# (
# x
# )
# )
# =
# v
# (
# x
# )
# u
# ′
# (
# x
# )
# −
# u
# (
# x
# )
# v
# ′
# (
# x
# )
# [
# v
# (
# x
# )
# ]
# 2
# ,
# dx
# d
# ​
#  (
# v(x)
# u(x)
# ​
#  )=
# [v(x)]
# 2
#
# v(x)u
# ′
#  (x)−u(x)v
# ′
#  (x)
# ​
#  ,
# where
# u
# (
# x
# )
# =
# x
# 2
# +
# 2
# x
# +
# 1
# u(x)=x
# 2
#  +2x+1 and
# v
# (
# x
# )
# =
# x
# −
# 1
# v(x)=x−1.
#
# First, compute the derivatives of
# u
# (
# x
# )
# u(x) and
# v
# (
# x
# )
# v(x):
#
# u
# ′
# (
# x
# )
# =
# 2
# x
# +
# 2
# ,
# u
# ′
#  (x)=2x+2,
# v
# ′
# (
# x
# )
# =
# 1.
# v
# ′
#  (x)=1.
# Now apply the quotient rule:
#
# f
# ′
# (
# x
# )
# =
# (
# x
# −
# 1
# )
# (
# 2
# x
# +
# 2
# )
# −
# (
# x
# 2
# +
# 2
# x
# +
# 1
# )
# (
# 1
# )
# (
# x
# −
# 1
# )
# 2
# .
# f
# ′
#  (x)=
# (x−1)
# 2
#
# (x−1)(2x+2)−(x
# 2
#  +2x+1)(1)
# ​
#  .
# Simplify the numerator:
#
# (
# x
# −
# 1
# )
# (
# 2
# x
# +
# 2
# )
# =
# (
# x
# −
# 1
# )
# ⋅
# 2
# (
# x
# +
# 1
# )
# =
# 2
# (
# x
# −
# 1
# )
# (
# x
# +
# 1
# )
# =
# 2
# (
# x
# 2
# −
# 1
# )
# ,
# (x−1)(2x+2)=(x−1)⋅2(x+1)=2(x−1)(x+1)=2(x
# 2
#  −1),
# (
# x
# 2
# +
# 2
# x
# +
# 1
# )
# =
# x
# 2
# +
# 2
# x
# +
# 1.
# (x
# 2
#  +2x+1)=x
# 2
#  +2x+1.
# Now substitute into the expression for
# f
# ′
# (
# x
# )
# f
# ′
#  (x):
#
# f
# ′
# (
# x
# )
# =
# 2
# (
# x
# 2
# −
# 1
# )
# −
# (
# x
# 2
# +
# 2
# x
# +
# 1
# )
# (
# x
# −
# 1
# )
# 2
# .
# f
# ′
#  (x)=
# (x−1)
# 2
#
# 2(x
# 2
#  −1)−(x
# 2
#  +2x+1)
# ​
#  .
# Simplify the numerator:
#
# 2
# (
# x
# 2
# −
# 1
# )
# =
# 2
# x
# 2
# −
# 2
# ,
# 2(x
# 2
#  −1)=2x
# 2
#  −2,
# 2
# x
# 2
# −
# 2
# −
# (
# x
# 2
# +
# 2
# x
# +
# 1
# )
# =
# 2
# x
# 2
# −
# 2
# −
# x
# 2
# −
# 2
# x
# −
# 1
# =
# x
# 2
# −
# 2
# x
# −
# 3.
# 2x
# 2
#  −2−(x
# 2
#  +2x+1)=2x
# 2
#  −2−x
# 2
#  −2x−1=x
# 2
#  −2x−3.
# Thus, the derivative is:
#
# f
# ′
# (
# x
# )
# =
# x
# 2
# −
# 2
# x
# −
# 3
# (
# x
# −
# 1
# )
# 2
# .
# f
# ′
#  (x)=
# (x−1)
# 2
#
# x
# 2
#  −2x−3
# ​
#  .

# %% [markdown]
#  Find the critical points
# To find the critical points, we set the derivative equal to 0:
#
# x
# 2
# −
# 2
# x
# −
# 3
# (
# x
# −
# 1
# )
# 2
# =
# 0.
# (x−1)
# 2
#
# x
# 2
#  −2x−3
# ​
#  =0.
# For the fraction to equal zero, the numerator must be zero. So, solve:
#
# x
# 2
# −
# 2
# x
# −
# 3
# =
# 0.
# x
# 2
#  −2x−3=0.
# Factoring the quadratic:
#
# (
# x
# −
# 3
# )
# (
# x
# +
# 1
# )
# =
# 0.
# (x−3)(x+1)=0.
# Thus, the solutions are:
#
# x
# =
# 3
# or
# x
# =
# −
# 1.
# x=3orx=−1.

# %% [markdown]
# Determine the nature of the critical points
# To determine whether each critical point corresponds to a maximum, minimum, or saddle point, we can check the second derivative or analyze the sign of the first derivative around the critical points.
#
# Let's consider the second derivative test or examine the behavior of
# f
# ′
# (
# x
# )
# f
# ′
#  (x) at the critical points. However, before that, we should note that
# x
# =
# 1
# x=1 is not in the domain of the function because the denominator of
# f
# (
# x
# )
# f(x) is 0 at
# x
# =
# 1
# x=1.
#
# Analyze around
# x
# =
# −
# 1
# x=−1 and
# x
# =
# 3
# x=3:
#
# For
# x
# =
# −
# 1
# x=−1:
# We observe that as
# x
# x approaches
# −
# 1
# −1 from the left, the function behaves differently from when approaching from the right. This suggests that
# x
# =
# −
# 1
# x=−1 could be a saddle point or a non-extremal critical point.
# For
# x
# =
# 3
# x=3:
# If we check the behavior of the function near
# x
# =
# 3
# x=3, we can conclude that this is likely a local minimum because the derivative changes sign from negative to positive.

# %% [markdown]
# Conclusion:
# The function has a local minimum at
# x
# =
# 3
# x=3.
# x
# =
# −
# 1
# x=−1 may be a point of discontinuity or a saddle point, and we should carefully consider its behavior based on limits or the nature of the function.
